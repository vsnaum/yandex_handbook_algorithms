# %% [markdown]
# ### <b>Числа Фибоначчи</b>
# Дано целое число 𝑛, необходимо вычислить 𝑛-е число Фибоначчи.
#
# <b>Формат ввода</b>
#
# Целое число 𝑛.
#
# <b>Ограничения: </b>
#
# 0≤𝑛≤45
#
# <b>Формат вывода</b>
#
# Выведите 𝐹_𝑛.

# %%
def inp_str(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line]
    return l


# слишком медленно для теста 35
def fib(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    return fib(n-1) + fib(n-2)


def fib2(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = fib_n1+fib_n2        
    return fib_res


n = int(inp_str(0))

print(fib2(n))

# %% [markdown]
# ### <b>Последняя цифра числа Фибоначчи</b>
#
# Дано число 𝑛, необходимо найти последнюю цифру 𝑛-го числа Фибоначчи.
#
# Числа Фибоначчи растут очень быстро, поэтому при их вычислении нужно быть аккуратным с переполнением. В данной задаче, впрочем, этой проблемы можно избежать, поскольку нас интересует только последняя цифра числа Фибоначчи: если 0≤a,b≤9 - последние цифры чисел 𝐹_𝑖 и 𝐹_𝑖+1 соответственно, то  (a+b)mod10 - последняя цифра числа 𝐹_𝑖+2.
#
# <b>Формат ввода</b>
#
# Целое число 𝑛.
#
# <b>Ограничения: </b>
#
# 0≤n≤10^6
#
# <b>Формат вывода</b>
#
# Последняя цифра из 𝐹_𝑛.

# %%
def inp_str(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line]
    return l


def fib2_last_num(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = (fib_n1+fib_n2) % 10        
    return fib_res


n = int(inp_str(0))

print(fib2_last_num(n))

# %% [markdown]
# ### <b>Огромное число Фибоначчи</b>
#
# Даны целые числа 𝑛 и 𝑚, необходимо найти остаток от деления 𝑛-го числа Фибоначчи на 𝑚.
#
# <b>Формат ввода</b>
#
# Целые числа 𝑛 и 𝑚.
#
# <b>Ограничения: </b>
#
# 1≤𝑛≤10^14, 2≤𝑚≤10^3.
#
# <b>Формат вывода</b>
#
# 𝐹_𝑛 mod 𝑚 - остаток от деления  𝐹_𝑛 на 𝑚.

# %%
def inp_str(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line]
    return l

def inp_list(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line].split(' ')
        for i in range(len(l)):
            l[i] = int(l[i])
    return l

def PisanoPeriod(m):
    current = 0
    next = 1
    period = 0
    while True:
        current, next = next, ((current + next) % m)
        period = period + 1
        if current == 0 and next == 1:
            return period

def fib2(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = fib_n1+fib_n2        
    return fib_res

def fib_mod_m(n_fib,m):
    new_n = n_fib % PisanoPeriod(m)
    return (fib2(new_n) % m)

n,m = inp_list(0)
print(fib_mod_m(n,m))

# %% [markdown]
# ### <b>Последняя цифра суммы чисел Фибоначчи </b>
# Дано число 𝑛, необходимо найти последнюю цифру суммы  𝐹_0 + 𝐹_1 + 𝐹_2 + … + 𝐹_𝑛
#
#
# <b>Формат ввода</b>
#
# Целое число 𝑛.
#
# <b>Ограничения: </b>
#
# 0≤𝑛≤10^14
#
# <b>Формат вывода</b>
#
# Последняя цифра суммы 𝐹_0 + 𝐹_1 + 𝐹_2 + … + 𝐹_𝑛.

# %%
# Последняя цифра суммы чисел Фибоначчи

def inp_str(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line]
    return l

def fib2(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = fib_n1+fib_n2        
    return fib_res

def s_last_naive(n):
    return (fib2(n+2) - 1) %10

# слишком медленно для теста 48
def s_last_slow(n):
    if n <= 2:
        return n
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n+2):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = (fib_n1+fib_n2)%10       
    if fib_res == 0:
        return 9
    return fib_res - 1

def PisanoPeriod(m):
    current = 0
    next = 1
    period = 0
    while True:
        current, next = next, ((current + next) % m)
        period = period + 1
        if current == 0 and next == 1:
            return period

def fib_mod_m(n_fib,m):
    new_n = n_fib % PisanoPeriod(m)
    return (fib2(new_n) % m)

def s_last(n):
    if n <= 2:
        return n
    res = fib_mod_m(n+2,10)    
    if res == 0:
        return 9
    return res - 1

def stress_test():
    for n in range(0,51):
        print(f"n={n}")
        naive = s_last_naive(n)
        elegant = s_last(n)
        assert naive == elegant, f"naive: {naive}  elegant: {elegant}"


n = int(inp_str(0))
print(s_last(n))

# %% [markdown]
# ### Последняя цифра частичной суммы чисел Фибоначчи
# Даны числа 𝑚 и 𝑛, необходимо найти последнюю цифру суммы 𝐹_𝑚 + 𝐹_𝑚+1 + … + 𝐹_𝑛
#
# <b>Формат ввода</b>
#
# Целые числа 𝑚 и 𝑛.
#
# <b>Ограничения: </b>
#
# 0≤𝑚≤𝑛≤10^14
#
# <b>Формат вывода</b>
#
# Последняя цифра суммы 𝐹_𝑚 + 𝐹_𝑚+1 + … + 𝐹_𝑛

# %%
# Последняя цифра частичной суммы чисел Фибоначчи

def inp_list(line,fname='input.txt'):
    with open(fname,'r') as f:
        l = f.readlines()[line].split(' ')
        for i in range(len(l)):
            l[i] = int(l[i])
    return l

def fib2(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        fib_n2 = 0
        fib_n1 = 1
        fib_res = 1
        for _ in range(2,n):
            fib_n2 = fib_n1
            fib_n1 = fib_res
            fib_res = fib_n1+fib_n2        
    return fib_res


def PisanoPeriod(m):
    current = 0
    next = 1
    period = 0
    while True:
        current, next = next, ((current + next) % m)
        period = period + 1
        if current == 0 and next == 1:
            return period


def ps_last(m,n):
    pp = PisanoPeriod(10)
    new_m = m % pp
    new_n = n % pp
    if new_n < new_m:
        new_n += pp

    s_m = fib2(new_m-1+2) - 1
    s_n = fib2(new_n+2) - 1
    ss = s_n - s_m
    
    return ss % 10

m,n = inp_list(0)


print(ps_last(m,n))
